# %%
#Distancias de los planetas desde el sol
Ear_dis = 149597870
Jup_dis = 778547200

# %%
#Distancia entre los dos en km y mi
Distance = Jup_dis - Ear_dis
print(f"La distancia entre la Tierra y Júpiter es de {Distance} km, \ny en millas es igual a {round(Distance*0.621)} mi.")
# Out:
# La distancia entre la Tierra y Júpiter es de 628949330 km,
# y en millas es igual a 390577534 mi

# %%
plan1 = input("Ingresa la distancia en km del primer planeta")
plan2 = input("Ingresa la distancia en km del segundo planeta")
dist = abs(int(plan1) - int(plan2))
print(f"La distancia entre planetas es de {dist} km \n y en millas es igual a {round(dist*.0621)} mi.")
# Out:
# La distancia entre planetas es de 50300000 km
#  y en millas es igual a 3123630
