# %%
ast_vel = 49
if(ast_vel > 25):
    print("¡Cuidado, un asteroide se acerca a la tierra a una velocidad de " + str(ast_vel) +" km/s!")
else 
    print("Hay un asteroide cerca, pero es muy lento para ser una amenaza.")
# Out:
# ¡Cuidado, un asteroide se acerca a la tierra a una velocidad de 49 km/s!

# %%
ast_vel1 = 19
if (ast_vel1 > 20):
    print("Hay un asteroide en la atmósfera, puede ser que veas un rayo de luz. ¡Sal a buscarlo!")
elif (ast_vel1 == 20):
    print("Hay un asteroide en la atmósfera, puede ser que veas un rayo de luz. ¡Sal a buscarlo!")
else:
    print("Hay un asteroide en la atmósfera, pero no es tan rápido como para generar un rayo de luz.")
# Out:
# Hay un asteroide en la atmósfera, pero no es tan rápido como para generar un rayo de luz.

# %%
astvel = 10
astdim = 22
if (astvel > 25 and astdim > 25 ):
    print("¡Cuidado, hay un asteroide peligroso que viene hacia la tierra!")
elif (astvel >=20):
    print("Hay un asteroide en la atmósfera, sal a buscar su luz")
elif (astdim < 25):
    print("Hay un asteroide, pero no hay peligro uwu")
else:
    print("Hay un asteroide, pero no hay peligro uwu")
# Out:
# Hay un asteroide, pero no hay peligro uwu
